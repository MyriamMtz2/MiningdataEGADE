# %%
# %ls
# Out:
#  adult.csv                   coches.csv             README.md
#  airline_data.csv            cwurData.csv           reg_data.csv
#  antropometria00.csv         data.csv               requirements.txt
#  antropometria-dataset.csv   datasets/              sample_pivot.csv
#  Book3.csv                   headbrain.csv          tips.csv
#  Canada.xlsx                 mic2.xlsx             'Untitled Folder'/
#  Cartwheeldata.csv           movies.csv             weight-height.csv
#  census.csv                  nhanes_2015_2016.csv
#  Clase3-act2.ipynb           pokemon.csv

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           coches.csv     pokemon.csv
# antropometria00.csv        cwurData.csv   reg_data.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('datasets/airline_data.csv',
               low_memory=False
              )
df.head(2)
# Out:
#    Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0     1295781  1998        2      4           2          4  1998-04-02
# 1     1125375  2013        2      5          13          1  2013-05-13
#
#   Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                AS                     19930                          AS
# 1                EV                     20366                          EV
#
#    ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# 0  ...           NaN          NaN          NaN            NaN
# 1  ...           NaN          NaN          NaN            NaN
#
#    Div5AirportSeqID Div5WheelsOn Div5TotalGTime Div5LongestGTime  \
# 0               NaN          NaN            NaN              NaN
# 1               NaN          NaN            NaN              NaN
#
#    Div5WheelsOff Div5TailNum
# 0            NaN         NaN
# 1            NaN         NaN
#
# [2 rows x 110 columns]

# %%
x=df.columns.tolist()
x.sort()
x
# Out:
# ['ActualElapsedTime',
#  'AirTime',
#  'ArrDel15',
#  'ArrDelay',
#  'ArrDelayMinutes',
#  'ArrTime',
#  'ArrTimeBlk',
#  'ArrivalDelayGroups',
#  'CRSArrTime',
#  'CRSDepTime',
#  'CRSElapsedTime',
#  'CancellationCode',
#  'Cancelled',
#  'CarrierDelay',
#  'DOT_ID_Reporting_Airline',
#  'DayOfWeek',
#  'DayofMonth',
#  'DepDel15',
#  'DepDelay',
#  'DepDelayMinutes',
#  'DepTime',
#  'DepTimeBlk',
#  'DepartureDelayGroups',
#  'Dest',
#  'DestAirportID',
#  'DestAirportSeqID',
#  'DestCityMarketID',
#  'DestCityName',
#  'DestState',
#  'DestStateFips',
#  'DestStateName',
#  'DestWac',
#  'Distance',
#  'DistanceGroup',
#  'Div1Airport',
#  'Div1AirportID',
#  'Div1AirportSeqID',
#  'Div1LongestGTime',
#  'Div1TailNum',
#  'Div1TotalGTime',
#  'Div1WheelsOff',
#  'Div1WheelsOn',
#  'Div2Airport',
#  'Div2AirportID',
#  'Div2AirportSeqID',
#  'Div2LongestGTime',
#  'Div2TailNum',
#  'Div2TotalGTime',
#  'Div2WheelsOff',
#  'Div2WheelsOn',
#  'Div3Airport',
#  'Div3AirportID',
# ...

# %%
df['DepartureDelayGroups'].max()
# Out:
# 12.0

# %%
df['DepDelay']
# Out:
# 0        0.0
# 1       -6.0
# 2       33.0
# 3       24.0
# 4       -9.0
#         ...
# 9437    -4.0
# 9438    21.0
# 9439     0.0
# 9440    -4.0
# 9441     0.0
# Name: DepDelay, Length: 9442, dtype: float64

# %%
df['DepDelay'].min()
# Out:
# -23.0

# %%
df['DepDelay'].max()
# Out:
# 988.0

# %%
df.groupby(['DepDelay','DepartureDelayGroups']).size()
# Out:
# DepDelay  DepartureDelayGroups
# -23.0     -2.0                    1
# -19.0     -2.0                    2
# -18.0     -2.0                    1
# -17.0     -2.0                    3
# -16.0     -2.0                    6
#                                  ..
#  403.0     12.0                   1
#  460.0     12.0                   1
#  600.0     12.0                   1
#  732.0     12.0                   1
#  988.0     12.0                   1
# Length: 224, dtype: int64

# %%
pd.pivot_table(df,
               index=['Year'],
               values='DepDelay',
               columns='DepartureDelayGroups',
               aggfunc='sum',
               margins= True
              )
# Out:
# DepartureDelayGroups   -2.0     -1.0      0.0      1.0      2.0      3.0  \
# Year
# 1987                    NaN    -20.0     81.0    145.0     36.0     97.0
# 1988                    NaN    -64.0    385.0    408.0    263.0    149.0
# 1989                    NaN    -84.0    450.0    417.0    231.0    196.0
# 1990                    NaN   -135.0    350.0    383.0    112.0     49.0
# 1991                    NaN   -120.0    425.0    291.0    361.0    209.0
# 1992                    NaN   -140.0    329.0    326.0    145.0    164.0
# 1993                    NaN   -161.0    381.0    267.0    271.0    305.0
# 1994                    NaN   -120.0    402.0    337.0    295.0    158.0
# 1995                    NaN   -183.0    490.0    433.0    256.0    399.0
# 1996                    NaN   -177.0    427.0    357.0    365.0    412.0
# 1997                    NaN   -224.0    387.0    284.0    264.0    200.0
# 1998                    NaN   -263.0    354.0    350.0    302.0    264.0
# ...

# %% [markdown]
# ## function Lambda
# #lambda  arguments : expression

# %%
x = lambda a: a + 2

# %%
x(5)
# Out:
# 7

# %%
x = lambda a: a * 2+10

# %%
x(5)
# Out:
# 20

# %%
y= lambda a, b: a+b-2

# %%
y(2,3)
# Out:
# 3

# %%
z= lambda a=0,b=0,c=0 : a+b-2*c

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    ['A+','A','A-','B+','B','B-','C+','C','C-','D+','D'],
    index =['excellent','excellent','excellent','good','good','good','ok','ok','ok','poor','poor'],
    columns=['Grades']
)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
type(df['Grades'])
# Out:
# pandas.core.series.Series

# %%
df['Grades'].astype('category')
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
orded = pd.CategoricalDtype(
    categories=['D','D+','C-','C','C+','B-','B','B+','A-','A','A+'],
    ordered=True)
grades= df['Grades'].astype(orded)
print(grades)
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]
