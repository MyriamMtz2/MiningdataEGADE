# %% [markdown]
# ##   Clase 2: Data wrangling

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy  as np

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           coches.csv     pokemon.csv
# antropometria00.csv        cwurData.csv   reg_data.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df= pd.read_excel ("datasets/Canada.xlsx",
                   sheet_name= "Canada by Citizenship",
                   skiprows= range(20),
                   skipfooter=2, 
                   engine="openpyxl"
                  )

# %%
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %%
df.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
df.head(2)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
#
#    DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 0  902  Developing regions    16  ...  2978  3436  3009  2652  2111  1746
# 1  901   Developed regions     1  ...  1450  1223   856   702   560   716
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
# 1   561   539   620   603
#
# [2 rows x 43 columns]

# %%
df.head(3)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
# 2  Immigrants  Foreigners      Algeria   903   Africa   912  Northern Africa
#
#    DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 0  902  Developing regions    16  ...  2978  3436  3009  2652  2111  1746
# 1  901   Developed regions     1  ...  1450  1223   856   702   560   716
# 2  902  Developing regions    80  ...  3616  3626  4807  3623  4005  5393
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
# 1   561   539   620   603
# 2  4752  4325  3774  4331
#
# [3 rows x 43 columns]

# %%
pd.set_option("display.max_columns", None)

# %%
pd.set_option("display.max_rows", None)

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Columns: 43 entries, Type to 2013
# dtypes: int64(37), object(6)
# memory usage: 65.6+ KB

# %%
df.shape
# Out:
# (195, 43)

# %%
df.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Type',
#  'Coverage',
#  'OdName',
#  'AREA',
#  'AreaName',
#  'REG',
#  'RegName',
#  'DEV',
#  'DevName',
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
df.drop([    'Type', 'Coverage',     'AREA',      'REG',  'DevName',], 
        axis = 1, 
        inplace = True
       )

# %%
df.rename(columns={"OdName":"Country","AreaName":"Continent"},
                   inplace=True
         )
df.head(2)
# Out:
#        Country Continent          RegName  DEV  1980  1981  1982  1983  1984  \
# 0  Afghanistan      Asia    Southern Asia  902    16    39    39    47    71
# 1      Albania    Europe  Southern Europe  901     1     0     0     0     0
#
#    1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# 0   340   496   741   828  1076  1028  1378  1170   713   858  1537  2212
# 1     0     1     2     2     3     3    21    56    96    71    63   113
#
#    1997  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# 0  2555  1999  2395  3326  4067  3697  3479  2978  3436  3009  2652  2111
# 1   307   574  1264  1816  1602  1021   853  1450  1223   856   702   560
#
#    2009  2010  2011  2012  2013
# 0  1746  1758  2203  2635  2004
# 1   716   561   539   620   603

# %%
df.iloc[:,3]
# Out:
# 0      902
# 1      901
# 2      902
# 3      902
# 4      901
# 5      902
# 6      902
# 7      902
# 8      902
# 9      901
# 10     901
# 11     902
# 12     902
# 13     902
# 14     902
# 15     902
# 16     901
# 17     901
# 18     902
# 19     902
# 20     902
# 21     902
# 22     901
# 23     902
# 24     902
# 25     902
# 26     901
# 27     902
# 28     902
# 29     902
# 30     902
# 31     902
# 32     901
# 33     902
# 34     902
# 35     902
# 36     902
# 37     902
# 38     902
# 39     902
# 40     902
# 41     902
# 42     902
# 43     902
# 44     901
# 45     902
# 46     902
# 47     901
# 48     902
# 49     902
# 50     901
# 51     902
# 52     902
# 53     902
# 54     902
# 55     902
# 56     902
# 57     902
# 58     902
# 59     901
# 60     902
# 61     902
# 62     901
# 63     901
# 64     902
# 65     902
# 66     902
# 67     901
# 68     902
# 69     901
# 70     902
# 71     902
# 72     902
# 73     902
# 74     902
# 75     902
# ...

# %% [markdown]
# # 1. How many people from Japan reached Canada during 1980 tp 2013?

# %%
df["Total"]=df.iloc[:,3:].sum(axis=1)

# %%
df.head()
# Out:
#           Country Continent          RegName  DEV  1980  1981  1982  1983  \
# 0     Afghanistan      Asia    Southern Asia  902    16    39    39    47
# 1         Albania    Europe  Southern Europe  901     1     0     0     0
# 2         Algeria    Africa  Northern Africa  902    80    67    71    69
# 3  American Samoa   Oceania        Polynesia  902     0     1     0     0
# 4         Andorra    Europe  Southern Europe  901     0     0     0     0
#
#    1984  1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  \
# 0    71   340   496   741   828  1076  1028  1378  1170   713   858  1537
# 1     0     0     1     2     2     3     3    21    56    96    71    63
# 2    63    44    69   132   242   434   491   872   795   717   595  1106
# 3     0     0     0     1     0     1     2     0     0     0     0     0
# 4     0     0     2     0     0     0     3     0     1     0     0     0
#
# ...

# %% [markdown]
# # iloc[RowStart:RowEnd,ColumnStart:ColumnEnd]

# %%
df.set_index("Country", 
             inplace=True)
df
# Out:
#                                                                           Continent  \
# Country
# Afghanistan                                                                    Asia
# Albania                                                                      Europe
# Algeria                                                                      Africa
# American Samoa                                                              Oceania
# Andorra                                                                      Europe
# Angola                                                                       Africa
# Antigua and Barbuda                                 Latin America and the Caribbean
# Argentina                                           Latin America and the Caribbean
# Armenia                                                                        Asia
# Australia                                                                   Oceania
# ...

# %%
df.index.name=None

# %%
df.loc["Japan"]
# Out:
# Continent            Asia
# RegName      Eastern Asia
# DEV                   901
# 1980                  701
# 1981                  756
# 1982                  598
# 1983                  309
# 1984                  246
# 1985                  198
# 1986                  248
# 1987                  422
# 1988                  324
# 1989                  494
# 1990                  379
# 1991                  506
# 1992                  605
# 1993                  907
# 1994                  956
# 1995                  826
# 1996                  994
# 1997                  924
# 1998                  897
# 1999                 1083
# 2000                 1010
# 2001                 1092
# 2002                  806
# 2003                  817
# 2004                  973
# 2005                 1067
# 2006                 1212
# 2007                 1250
# 2008                 1284
# 2009                 1194
# 2010                 1168
# 2011                 1265
# ...

# %% [markdown]
# # Conclusion
#
#  In total 27707 people emmigrates from Japan to Canada

# %%
df.columns = list(map(str,df.columns))
df.columns
# Out:
# Index(['Continent', 'RegName', 'DEV', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', 'Total'],
#       dtype='object')

# %%
type(df.loc["Japan"])
# Out:
# pandas.core.series.Series

# %%
df.iloc[87]
# Out:
# Continent            Asia
# RegName      Eastern Asia
# DEV                   901
# 1980                  701
# 1981                  756
# 1982                  598
# 1983                  309
# 1984                  246
# 1985                  198
# 1986                  248
# 1987                  422
# 1988                  324
# 1989                  494
# 1990                  379
# 1991                  506
# 1992                  605
# 1993                  907
# 1994                  956
# 1995                  826
# 1996                  994
# 1997                  924
# 1998                  897
# 1999                 1083
# 2000                 1010
# 2001                 1092
# 2002                  806
# 2003                  817
# 2004                  973
# 2005                 1067
# 2006                 1212
# 2007                 1250
# 2008                 1284
# 2009                 1194
# 2010                 1168
# 2011                 1265
# ...

# %%
df[df.index=="Mexico"]
# Out:
#                               Continent          RegName  DEV  1980  1981  \
# Mexico  Latin America and the Caribbean  Central America  902   409   394
#
#         1982  1983  1984  1985  1986  1987  1988  1989  1990  1991  1992  \
# Mexico   491   490   509   425   667   813   916  1017  1193  1134  1189
#
#         1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  \
# Mexico  1139   776   758  1234  1689  1379  1679  1662  1939  1894  1754
#
#         2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  Total
# Mexico  2259  2837  2844  3239  2856  3092  3865  3947  4227  3996  59614

# %%
df.loc["Japan", "2000"]
# Out:
# 1010

# %%
df.loc["Japan", ["2000", "2010"]]
# Out:
# 2000    1010
# 2010    1168
# Name: Japan, dtype: object

# %% [markdown]
# # Data filtering based on criteria

# %%
condition=df["Continent"]=="Asia"
print(condition)
# Out:
# Afghanistan                                              True
# Albania                                                 False
# Algeria                                                 False
# American Samoa                                          False
# Andorra                                                 False
# Angola                                                  False
# Antigua and Barbuda                                     False
# Argentina                                               False
# Armenia                                                  True
# Australia                                               False
# Austria                                                 False
# Azerbaijan                                               True
# Bahamas                                                 False
# Bahrain                                                  True
# Bangladesh                                               True
# ...

# %%
df[condition]
# Out:
#                                                Continent             RegName  \
# Afghanistan                                         Asia       Southern Asia
# Armenia                                             Asia        Western Asia
# Azerbaijan                                          Asia        Western Asia
# Bahrain                                             Asia        Western Asia
# Bangladesh                                          Asia       Southern Asia
# Bhutan                                              Asia       Southern Asia
# Brunei Darussalam                                   Asia  South-Eastern Asia
# Cambodia                                            Asia  South-Eastern Asia
# China                                               Asia        Eastern Asia
# China, Hong Kong Special Administrative Region      Asia        Eastern Asia
# China, Macao Special Administrative Region          Asia        Eastern Asia
# ...

# %%
df[condition & (df["RegName"]=="Southern Asia")]
# Out:
#                            Continent        RegName  DEV  1980  1981  1982  \
# Afghanistan                     Asia  Southern Asia  902    16    39    39
# Bangladesh                      Asia  Southern Asia  902    83    84    86
# Bhutan                          Asia  Southern Asia  902     0     0     0
# India                           Asia  Southern Asia  902  8880  8670  8147
# Iran (Islamic Republic of)      Asia  Southern Asia  902  1172  1429  1822
# Maldives                        Asia  Southern Asia  902     0     0     0
# Nepal                           Asia  Southern Asia  902     1     1     6
# Pakistan                        Asia  Southern Asia  902   978   972  1201
# Sri Lanka                       Asia  Southern Asia  902   185   371   290
#
#                             1983  1984  1985  1986   1987   1988   1989  \
# Afghanistan                   47    71   340   496    741    828   1076
# Bangladesh                    81    98    92   486    503    476    387
# ...

# %%
nDf= df[condition & (df["RegName"]=="Southern Asia")]

# %%
nDf.describe()
# Out:
#          DEV         1980         1981         1982         1983         1984  \
# count    9.0     9.000000     9.000000     9.000000     9.000000     9.000000
# mean   902.0  1257.222222  1285.111111  1287.888889  1128.555556  1067.444444
# std      0.0  2893.967207  2815.988922  2652.848160  2392.058481  1865.123194
# min    902.0     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    902.0     1.000000     1.000000     6.000000     1.000000     2.000000
# 50%    902.0    83.000000    84.000000    86.000000    81.000000    98.000000
# 75%    902.0   978.000000   972.000000  1201.000000   900.000000  1086.000000
# max    902.0  8880.000000  8670.000000  8147.000000  7338.000000  5704.000000
#
#               1985         1986          1987          1988          1989  \
# count     9.000000     9.000000      9.000000      9.000000      9.000000
# mean    850.444444  1385.333333   2216.333333   2247.222222   2290.111111
# ...

# %% [markdown]
# # Create a Dataframe

# %%
df1 =pd.DataFrame({"a":[1,3,5,7,9],
                 "b":["one","three","five","seven","nine"]
                }
                )
df1
# Out:
#    a      b
# 0  1    one
# 1  3  three
# 2  5   five
# 3  7  seven
# 4  9   nine

# %%
df2=pd.DataFrame({"c":[2,4,6,7,9],
                "d":["two", "four", "six", "seven", "nine"]
                 }
                )
df2
# Out:
#    c      d
# 0  2    two
# 1  4   four
# 2  6    six
# 3  7  seven
# 4  9   nine

# %%
df3 = pd.concat([df1,df2],
               axis = 1
               )
df3
# Out:
#    a      b  c      d
# 0  1    one  2    two
# 1  3  three  4   four
# 2  5   five  6    six
# 3  7  seven  7  seven
# 4  9   nine  9   nine

# %%
df4= pd.concat([df1,df2],
               axis=0
              )
df4
# Out:
#      a      b    c      d
# 0  1.0    one  NaN    NaN
# 1  3.0  three  NaN    NaN
# 2  5.0   five  NaN    NaN
# 3  7.0  seven  NaN    NaN
# 4  9.0   nine  NaN    NaN
# 0  NaN    NaN  2.0    two
# 1  NaN    NaN  4.0   four
# 2  NaN    NaN  6.0    six
# 3  NaN    NaN  7.0  seven
# 4  NaN    NaN  9.0   nine

# %%
x=pd.DataFrame ({"a":[2, np.nan,3,8],
                 "b":[4,5,7,8],
                 "c":[2,4,np.nan,8]
                }
               )
x
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 1  NaN  5  4.0
# 2  3.0  7  NaN
# 3  8.0  8  8.0

# %%
df1= x
df2= x
df3= x

# %%
df1.dropna(axis=0)
df1
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 1  NaN  5  4.0
# 2  3.0  7  NaN
# 3  8.0  8  8.0

# %%
df2.dropna(axis=1)
df2
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 1  NaN  5  4.0
# 2  3.0  7  NaN
# 3  8.0  8  8.0

# %%
df3
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 1  NaN  5  4.0
# 2  3.0  7  NaN
# 3  8.0  8  8.0

# %%
df3.dropna()
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 3  8.0  8  8.0

# %%
df3
# Out:
#      a  b    c
# 0  2.0  4  2.0
# 1  NaN  5  4.0
# 2  3.0  7  NaN
# 3  8.0  8  8.0

# %%
df4.loc["Total"]=df4.sum(numeric_only=True,
                       axis=0)

# %%
df4
# Out:
#           a      b     c      d
# 0       1.0    one   NaN    NaN
# 1       3.0  three   NaN    NaN
# 2       5.0   five   NaN    NaN
# 3       7.0  seven   NaN    NaN
# 4       9.0   nine   NaN    NaN
# 0       NaN    NaN   2.0    two
# 1       NaN    NaN   4.0   four
# 2       NaN    NaN   6.0    six
# 3       NaN    NaN   7.0  seven
# 4       NaN    NaN   9.0   nine
# Total  25.0    NaN  28.0    NaN
