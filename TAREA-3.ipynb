# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           coches.csv     pokemon.csv
# antropometria00.csv        cwurData.csv   reg_data.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          movies.csv

# %%
## Instalar pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
##Leer data set

# %%
df=pd.read_csv('datasets/antropometria-dataset.csv',
                 low_memory=False
                )
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
## pivot table sacando peso promedio

# %%
pd.pivot_table(df,
               index = 'desc_ent',
               values = 'peso',
               aggfunc = 'mean'
              )
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# OAXACA                           58.800067
# ...

# %%
## 1. Cual es el promedio de peso en queretaro? 64.547342

# %%
## pivot table sacando mediana del peso

# %%
avBi = pd.pivot_table(df,
                      index = ['desc_ent', "sexo"],
                      values = ['peso'],
                      aggfunc = 'median',
                     )
avBi
# Out:
#                                          peso
# desc_ent                        sexo
# AGUASCALIENTES                  1     69.9500
#                                 2     63.7000
# BAJA CALIFORNIA                 1     70.6500
#                                 2     64.2000
# BAJA CALIFORNIA SUR             1     76.6500
# ...                                       ...
# VERACRUZ DE IGNACIO DE LA LLAVE 2     59.4725
# YUCATAN                         1     66.0000
#                                 2     59.5750
# ZACATECAS                       1     65.3000
#                                 2     61.6250
#
# [64 rows x 1 columns]

# %%
DATAmediana=avBi
DATAmediana
# Out:
#                                          peso
# desc_ent                        sexo
# AGUASCALIENTES                  1     69.9500
#                                 2     63.7000
# BAJA CALIFORNIA                 1     70.6500
#                                 2     64.2000
# BAJA CALIFORNIA SUR             1     76.6500
# ...                                       ...
# VERACRUZ DE IGNACIO DE LA LLAVE 2     59.4725
# YUCATAN                         1     66.0000
#                                 2     59.5750
# ZACATECAS                       1     65.3000
#                                 2     61.6250
#
# [64 rows x 1 columns]

# %%
pd.set_option('max_rows', None)
pd.set_option('max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

print(DATAmediana)
# Out:
#                                          peso
# desc_ent                        sexo
# AGUASCALIENTES                  1     69.9500
#                                 2     63.7000
# BAJA CALIFORNIA                 1     70.6500
#                                 2     64.2000
# BAJA CALIFORNIA SUR             1     76.6500
#                                 2     68.5500
# CAMPECHE                        1     67.3500
#                                 2     62.3750
# CHIAPAS                         1     59.2000
#                                 2     56.0250
# CHIHUAHUA                       1     69.3000
#                                 2     64.6250
# COAHUILA DE ZARAGOZA            1     68.3000
#                                 2     67.3000
# COLIMA                          1     71.7000
#                                 2     66.0000
# DISTRITO FEDERAL                1     69.0000
#                                 2     61.4500
# DURANGO                         1     70.3500
# ...

# %%
## 2. Cual es la madiana de sexo 2 de Jalsico??   65.5875

# %%
avBimean = pd.pivot_table(df,
                      index = ['desc_ent', "sexo"],
                      values = ['peso'],
                      aggfunc = 'mean',
                     )
avBimean
# Out:
#                                            peso
# desc_ent                        sexo
# AGUASCALIENTES                  1     69.985381
#                                 2     63.254292
# BAJA CALIFORNIA                 1     71.391818
#                                 2     65.893667
# BAJA CALIFORNIA SUR             1     75.561015
#                                 2     68.168959
# CAMPECHE                        1     68.622637
#                                 2     62.920493
# CHIAPAS                         1     58.365222
#                                 2     57.096111
# CHIHUAHUA                       1     68.892642
#                                 2     64.815295
# COAHUILA DE ZARAGOZA            1     68.873094
#                                 2     67.467348
# COLIMA                          1     70.998878
#                                 2     66.978393
# DISTRITO FEDERAL                1     69.460661
#                                 2     61.654128
# ...

# %%
print (avBimean)
# Out:
#                                            peso
# desc_ent                        sexo
# AGUASCALIENTES                  1     69.985381
#                                 2     63.254292
# BAJA CALIFORNIA                 1     71.391818
#                                 2     65.893667
# BAJA CALIFORNIA SUR             1     75.561015
#                                 2     68.168959
# CAMPECHE                        1     68.622637
#                                 2     62.920493
# CHIAPAS                         1     58.365222
#                                 2     57.096111
# CHIHUAHUA                       1     68.892642
#                                 2     64.815295
# COAHUILA DE ZARAGOZA            1     68.873094
#                                 2     67.467348
# COLIMA                          1     70.998878
#                                 2     66.978393
# DISTRITO FEDERAL                1     69.460661
#                                 2     61.654128
# ...

# %%
avBimean['peso'].min()
# Out:
# 57.09611111111111

# %%
## 3.Cual es el valor minimo del promedio del sexo 2. ?? 57.09611

# %%
df=pd.read_csv('datasets/adult.csv',
                 low_memory=False
                )
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# 0          2174             0              40   United-States     <=50K
# 1             0             0              13   United-States     <=50K

# %%
avBiadults = pd.pivot_table(df,
                      index = ['marital-status', "education"],
                      values = ['age'],
                      aggfunc = 'mean',
                     )
avBiadults
# Out:
#                                             age
# marital-status         education
#  Divorced               10th          44.133333
#                         11th          41.230769
#                         12th          41.333333
#                         1st-4th       62.700000
#                         5th-6th       53.700000
#                         7th-8th       49.452055
#                         9th           46.281250
#                         Assoc-acdm    41.064039
#                         Assoc-voc     40.653846
#                         Bachelors     44.243590
#                         Doctorate     49.303030
#                         HS-grad       42.363918
#                         Masters       47.278970
#                         Preschool     36.000000
#                         Prof-school   44.127273
#                         Some-college  42.327409
#  Married-AF-spouse      Assoc-acdm    31.500000
#                         Assoc-voc     29.000000
# ...

# %%
## 4.Cual es el promedio de edad de los divorciados con Hs-grand??   42.363918
